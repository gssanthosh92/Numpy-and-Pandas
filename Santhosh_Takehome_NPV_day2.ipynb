# %% [markdown]
# # TAKE HOME LAB-EXERCISE - 02

# %% [markdown]
# (Kaggle games Dataset)
#
#  We will be using the [games Dataset](https://www.kaggle.com/gutsyrobot/games-data/data) from Kaggle.
#
# **TAKE HOME LAB EXERCISE** answer below question.

# %%
import pandas as pd
import os

# %% [markdown]
# **Q.no(1). load the Data 'games.csv' as games.**

# %%
games = pd.read_csv('games.csv')

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(2). Check the head of the DataFrame.**

# %%
games.head()
# Out:
#        id       type                                       name  \
# 0   12333  boardgame                          Twilight Struggle
# 1  120677  boardgame                              Terra Mystica
# 2  102794  boardgame                  Caverna: The Cave Farmers
# 3   25613  boardgame  Through the Ages: A Story of Civilization
# 4    3076  boardgame                                Puerto Rico
#
#    yearpublished  minplayers  maxplayers  playingtime  minplaytime  \
# 0         2005.0         2.0         2.0        180.0        180.0
# 1         2012.0         2.0         5.0        150.0         60.0
# 2         2013.0         1.0         7.0        210.0         30.0
# 3         2006.0         2.0         4.0        240.0        240.0
# 4         2002.0         2.0         5.0        150.0         90.0
#
#    maxplaytime  minage  users_rated  average_rating  bayes_average_rating  \
# 0        180.0    13.0        20113         8.33774               8.22186
# ...

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(3)How many rows and columns are there.**

# %%
games.shape
# Out:
# (81312, 20)

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(4). What is the average Playingtime of all the players in the dataset.**

# %%
games['playingtime'].mean()
# Out:
# 51.63478827682052

# %% [markdown]
# -------------------

# %% [markdown]
# **Q.no(5).What is the highest number of comments received for a game.**

# %%
games['total_comments'].max()
# Out:
# 11798

# %% [markdown]
# -------

# %% [markdown]
# **Q.no(6).What is the name of the game with id 1500.**

# %%
print(games[games['id']==1500]['name'].values)
# Out:
# ['Zocken']

# %% [markdown]
# ------

# %% [markdown]
# **Q.no(7).which year was game with id 1600 was published.**

# %%
print(games[games['id']==1600]['yearpublished'].values)
# Out:
# [1986.]

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(8).Which game has received highest number of comments.**

# %%
print(set(games[games['total_comments']==games['total_comments'].max()]['name'].values))
# Out:
# {'Catan'}

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(9).Which games have received least number of comments**

# %%
print(games[games['total_comments']==games['total_comments'].min()]['name'].values)
# Out:
# ['Looney Leo' 'Dump' 'Field of Fire' ... 'BEARanoia' 'Freight'
#  'Bingo Animal Kids']

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(10).How many unique games are there in the dataset.**

# %%
print(games['name'].value_counts().count())
# Out:
# 76035

# %% [markdown]
# ----

# %% [markdown]
# **Q.no(11).How many boardgames and boardgameexpansions are there in the dataset.**

# %%
print(games['type'].value_counts())
# Out:
# boardgame             70820
# boardgameexpansion    10492
# Name: type, dtype: int64

# %% [markdown]
# ----

# %% [markdown]
# **Q.no(12) Show the average ratings of games in ascending order.**

# %%
games.sort_values(by='average_rating')
# Out:
#            id                type  \
# 81311  184451           boardgame
# 46614   57399           boardgame
# 46615   57401           boardgame
# 46616   57402           boardgame
# 46617   57407           boardgame
# 46621   57473           boardgame
# 19583   12381           boardgame
# 46624   57510           boardgame
# 46625   57511           boardgame
# 46629   57558           boardgame
# 46630   57563           boardgame
# 46635   57603           boardgame
# 46636   57606           boardgame
# 46637   57607           boardgame
# 46641   57662           boardgame
# 46642   57664           boardgame
# 46643   57665           boardgame
# 46644   57666           boardgame
# 46646   57669           boardgame
# 46647   57671           boardgame
# 46648   57672  boardgameexpansion
# 46650   57674           boardgame
# 46613   57386           boardgame
# 46611   57348           boardgame
# 46603   57322           boardgame
# 46597   57305           boardgame
# ...

# %% [markdown]
# ----

# %% [markdown]
# **Q.no(13) Show the average ratings of games in ascending order.**

# %%
games.sort_values(by='average_rating')
# Out:
#            id                type  \
# 81311  184451           boardgame
# 46614   57399           boardgame
# 46615   57401           boardgame
# 46616   57402           boardgame
# 46617   57407           boardgame
# 46621   57473           boardgame
# 19583   12381           boardgame
# 46624   57510           boardgame
# 46625   57511           boardgame
# 46629   57558           boardgame
# 46630   57563           boardgame
# 46635   57603           boardgame
# 46636   57606           boardgame
# 46637   57607           boardgame
# 46641   57662           boardgame
# 46642   57664           boardgame
# 46643   57665           boardgame
# 46644   57666           boardgame
# 46646   57669           boardgame
# 46647   57671           boardgame
# 46648   57672  boardgameexpansion
# 46650   57674           boardgame
# 46613   57386           boardgame
# 46611   57348           boardgame
# 46603   57322           boardgame
# 46597   57305           boardgame
# ...

# %% [markdown]
# ----

# %% [markdown]
# **Q.no(14).What is the dense rank order of the games as per there average rating.**

# %%
games['dense_rank']=games['average_rating'].rank(ascending=True,method='dense')
games
# Out:
#            id                type  \
# 0       12333           boardgame
# 1      120677           boardgame
# 2      102794           boardgame
# 3       25613           boardgame
# 4        3076           boardgame
# 5       31260           boardgame
# 6      124742           boardgame
# 7       96848           boardgame
# 8       84876           boardgame
# 9       72125           boardgame
# 10       2651           boardgame
# 11     164153           boardgame
# 12     115746           boardgame
# 13     121921           boardgame
# 14      35677           boardgame
# 15      28720           boardgame
# 16     126163           boardgame
# 17     150376           boardgame
# 18      68448           boardgame
# 19      18602           boardgame
# 20     122515           boardgame
# 21      40834           boardgame
# 22      62219           boardgame
# 23      28143           boardgame
# 24     103885           boardgame
# 25         93           boardgame
# ...

# %% [markdown]
# ------

# %% [markdown]
# # --------------------------------HAPPY LEARNING---------------------------------------

# %% [markdown]
# -------
