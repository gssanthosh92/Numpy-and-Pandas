# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Drop

# %%
df = pd.read_csv("profit.csv")
print(df)
# Out:
#           Vol  Rev  Exp Catg  EmpCnt   HQ
# HCL       931  863  605  Pub    1935  NCR
# MRF       992  821  665  Pub    1154  Che
# ISROACL   931  881  650  Gov    1361  Blr
# Reliance  899  217  674  Pub    1443  Mum
# BCCI      925  839  615  Pvt     154  Mum
# Birla     900  874  676  Pub    1379  Kol
# Flipkart  966  805  695  Pvt     119  Blr
# TSL       966  863  608  Pub    1656  Jmd
# IR        954  833  609  Gov   13023  NCR

# %%
df.drop('MRF',axis=0)
# Out:
#           Vol  Rev  Exp Catg  EmpCnt   HQ
# HCL       931  863  605  Pub    1935  NCR
# ISROACL   931  881  650  Gov    1361  Blr
# Reliance  899  217  674  Pub    1443  Mum
# BCCI      925  839  615  Pvt     154  Mum
# Birla     900  874  676  Pub    1379  Kol
# Flipkart  966  805  695  Pvt     119  Blr
# TSL       966  863  608  Pub    1656  Jmd
# IR        954  833  609  Gov   13023  NCR

# %%
df.drop(['Rev','Exp'],axis=1)
# Out:
#           Vol Catg  EmpCnt   HQ
# HCL       931  Pub    1935  NCR
# MRF       992  Pub    1154  Che
# ISROACL   931  Gov    1361  Blr
# Reliance  899  Pub    1443  Mum
# BCCI      925  Pvt     154  Mum
# Birla     900  Pub    1379  Kol
# Flipkart  966  Pvt     119  Blr
# TSL       966  Pub    1656  Jmd
# IR        954  Gov   13023  NCR

# %%
df['temp'] = np.NaN
df
# Out:
#           Vol  Rev  Exp Catg  EmpCnt   HQ  temp
# HCL       931  863  605  Pub    1935  NCR   NaN
# MRF       992  821  665  Pub    1154  Che   NaN
# ISROACL   931  881  650  Gov    1361  Blr   NaN
# Reliance  899  217  674  Pub    1443  Mum   NaN
# BCCI      925  839  615  Pvt     154  Mum   NaN
# Birla     900  874  676  Pub    1379  Kol   NaN
# Flipkart  966  805  695  Pvt     119  Blr   NaN
# TSL       966  863  608  Pub    1656  Jmd   NaN
# IR        954  833  609  Gov   13023  NCR   NaN

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Vol, Rev, Exp, Catg, EmpCnt, HQ, temp]
# Index: []

# %%
df.fillna(234)
# Out:
#           Vol  Rev  Exp Catg  EmpCnt   HQ   temp
# HCL       931  863  605  Pub    1935  NCR  234.0
# MRF       992  821  665  Pub    1154  Che  234.0
# ISROACL   931  881  650  Gov    1361  Blr  234.0
# Reliance  899  217  674  Pub    1443  Mum  234.0
# BCCI      925  839  615  Pvt     154  Mum  234.0
# Birla     900  874  676  Pub    1379  Kol  234.0
# Flipkart  966  805  695  Pvt     119  Blr  234.0
# TSL       966  863  608  Pub    1656  Jmd  234.0
# IR        954  833  609  Gov   13023  NCR  234.0

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:2em;color:#8707ff;"> Duplicate

# %%
df = pd.read_csv("Humidity1.csv")
df
# Out:
#          date      city  temperature  humidity
# 0  05-01-2017  new york           65        56
# 1  05-01-2017  new york           61        54
# 2  05-02-2017  new york           70        60
# 3  05-02-2017  new york           71        62
# 4  05-01-2017    mumbai           75        80
# 5  05-01-2017    mumbai           78        83
# 6  05-02-2017    mumbai           82        85
# 7  05-02-2017    mumbai           80        26
# 8  05-01-2017    mumbai           75        80

# %%
df.drop_duplicates()
# Out:
#          date      city  temperature  humidity
# 0  05-01-2017  new york           65        56
# 1  05-01-2017  new york           61        54
# 2  05-02-2017  new york           70        60
# 3  05-02-2017  new york           71        62
# 4  05-01-2017    mumbai           75        80
# 5  05-01-2017    mumbai           78        83
# 6  05-02-2017    mumbai           82        85
# 7  05-02-2017    mumbai           80        26

# %%
df.drop_duplicates(keep='last')
# Out:
#          date      city  temperature  humidity
# 0  05-01-2017  new york           65        56
# 1  05-01-2017  new york           61        54
# 2  05-02-2017  new york           70        60
# 3  05-02-2017  new york           71        62
# 5  05-01-2017    mumbai           78        83
# 6  05-02-2017    mumbai           82        85
# 7  05-02-2017    mumbai           80        26
# 8  05-01-2017    mumbai           75        80

# %%
df.drop_duplicates(['city'], keep='first')
# Out:
#          date      city  temperature  humidity
# 0  05-01-2017  new york           65        56
# 4  05-01-2017    mumbai           75        80

# %%
df.drop_duplicates(['city'], keep='last')
# Out:
#          date      city  temperature  humidity
# 3  05-02-2017  new york           71        62
# 8  05-01-2017    mumbai           75        80

# %% [markdown]
# #### Lets check which rows are duplicated

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8     True
# dtype: bool

# %% [markdown]
# False means no duplication. We checked for the entire row. None of the row is matching with each other completely.

# %% [markdown]
# ### Lets check for the duplication in certain columns

# %%
df.duplicated(['date'])
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# dtype: bool

# %% [markdown]
# ### Lets check for the duplication in two columns together?

# %%
df.duplicated(['date','city'])
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7     True
# 8     True
# dtype: bool

# %%
mask = df.duplicated(['date','city'], keep='last')
print(mask)
print(df[mask])
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# 6     True
# 7    False
# 8    False
# dtype: bool
#          date      city  temperature  humidity
# 0  05-01-2017  new york           65        56
# 2  05-02-2017  new york           70        60
# 4  05-01-2017    mumbai           75        80
# 5  05-01-2017    mumbai           78        83
# 6  05-02-2017    mumbai           82        85
